# %% [markdown]
# <a href="https://colab.research.google.com/github/ANSHUSHARMA1231/Machine_Learning/blob/main/PREDICTION_OF_PERCENTAGE.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # \#1 Prediction using Supervised ML
# #    Predict the percentage of a student based on the no. of study hours

# %%
# import libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
# import data
data=pd.read_csv('http://bit.ly/w-data')

# %%
# view data
data.head()
# Out:
#    Hours  Scores
# 0    2.5      21
# 1    5.1      47
# 2    3.2      27
# 3    8.5      75
# 4    3.5      30

# %%
# visualize data
data.plot(x='Hours',y='Scores',style='v')
plt.title('hours vs scores')
plt.xlabel('hours of study')
plt.ylabel('scores in percentage')
plt.show()

# %%
# divide the data into attributes and labels
X=data.iloc[:, :-1].values
Y=data.iloc[:, 1].values

# %%
# now we have to split the data into training and testing data
from sklearn.model_selection import train_test_split
X_train, X_test, Y_train, Y_test=train_test_split(X,Y,test_size=0.44,random_state=2529)

# %%
# training the algorithm
from sklearn.linear_model import LinearRegression
model=LinearRegression()
model.fit(X_train, Y_train)
# Out:
# LinearRegression()

# %%
# plotting the regression line
line= model.coef_*X + model.intercept_
plt.scatter(X,Y)
plt.plot(X, line)
plt.show()

# %%
# predictions with our trained model
pred_score=model.predict(X_test)
print(pred_score)
# Out:
# [53.16089002 46.99258314 33.62791822 20.2632533  50.07673658 88.11462904
#  95.31098708 26.43156018 71.66581068 57.27309461 28.48766248]

# %%
# comparing Actual with predicted
df=pd.DataFrame({'Actual':Y_test, 'Predicted':pred_score})
df
# Out:
#     Actual  Predicted
# 0       47  53.160890
# 1       41  46.992583
# 2       27  33.627918
# 3       24  20.263253
# 4       54  50.076737
# 5       75  88.114629
# 6       88  95.310987
# 7       30  26.431560
# 8       76  71.665811
# 9       60  57.273095
# 10      30  28.487662

# %%
hours=[[9.25]]
score_pred=model.predict(hours)
print("number of hours(study): {}".format(hours))
print("predicted score(percentage): {}".format(score_pred[0]))
# Out:
# number of hours(study): [[9.25]]
# predicted score(percentage): 95.82501265096187

# %%
# evaluating the performance of the model
from sklearn import metrics
print('Mean Absolute Error:',metrics.mean_absolute_error(Y_test,pred_score))
# Out:
# Mean Absolute Error: 5.364444514632203
